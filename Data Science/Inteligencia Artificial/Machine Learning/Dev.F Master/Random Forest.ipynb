# %%
 ### El método random forest selecciona de manera aleatoria observaciones del df, y de igual manera, deja deliberadamente fuera
  #de la base de datos otras. 
        # arboles de clasif o regres pero pluralizado en cientos o miles
        # los resultados de sus modelos permiten obtener:
            # la media en caso de variab numerics
            # la categoria con mas casos

from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

inpath = "D:/Disco D/Big Data/Data/"
df = pd.read_csv(inpath + "base_datos_2008.csv")
df = df.dropna(subset = ["ArrDelay"]) 
df = df.sample(frac=1)
df = df.head(100000)
df_test = df.tail(100000)
df
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2960796  2008      5          15          4   1108.0        1055   1353.0
# 3499549  2008      6          29          7   2022.0        1840   2358.0
# 6600966  2008     12          25          4   1736.0        1737   1914.0
# 609106   2008      2           3          7   1607.0        1545   1948.0
# 5640190  2008     10          19          7   1450.0        1452   1617.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 1399958  2008      3          27          4   1338.0        1325   1637.0
# 1289728  2008      3          31          1   1524.0        1455   1634.0
# 3229158  2008      6          23          1   1656.0        1650   1819.0
# 3588263  2008      6           7          6    552.0         600    745.0
# 5160891  2008      9           1          1    701.0         702    915.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
clf =tree.DecisionTreeClassifier() #otros param max_features = n°, bootstrap = boolean --> realiza muestreo con reemplazo
                                                                    # generando muestras aleatorias de las filas para rehacer los 
                                                                    # bosques

x = df[["AirTime", "Distance", "TaxiIn", "TaxiOut", "DepTime", "DepDelay"]]
x_test = df_test[["AirTime", "Distance", "TaxiIn", "TaxiOut", "DepTime", "DepDelay"]]
y = df["ArrDelay"] > 10
y_test = df_test["ArrDelay"] > 10 # variable respuesta, booleana

clf = clf.fit(x,y)
y_pred_test = clf.predict(x_test)
np.mean(y_test == y_pred_test)
# Out:
# 1.0

# %%
clf = RandomForestClassifier(n_estimators = 100) #esta generando 100 arboles
clf.fit(x,y)
y_pred_test = clf.predict(x_test)

clf.feature_importances_ # nos da la reelevancia de las variables usadas, em el caso de abajo, la mas relevante es Depdelay
# Out:
# array([0.07637332, 0.0852916 , 0.05414406, 0.13689945, 0.07973329,
#        0.56755828])

# %%
np.mean(y_test == y_pred_test)
# Out:
# 0.99999

# %%
# RandomForestRegressor() #para arboles de regresion, se usa igual
