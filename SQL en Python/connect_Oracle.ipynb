# %%
import cx_Oracle

# Configurar las propiedades de la conexión

'''
jdbc_hostname = "tb-az-svr-sql01.database.windows.net"
jdbc_database = "TBDatawarehouseDB"
jdbc_url = f"jdbc:sqlserver://{jdbc_hostname}:1433;database={jdbc_database}"
jdbc_properties = {
    "user": "tb_bi_diego_torres",
    "password": "P10m4*%|]XwC",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}


stxbil_accessreport_comar
Fj348jv0sMxss32N1cUrn1
comar.datamart.secutix.com
'''
# Out:
# '\njdbc_hostname = "tb-az-svr-sql01.database.windows.net"\njdbc_database = "TBDatawarehouseDB"\njdbc_url = f"jdbc:sqlserver://{jdbc_hostname}:1433;database={jdbc_database}"\njdbc_properties = {\n    "user": "tb_bi_diego_torres",\n    "password": "P10m4*%|]XwC",\n    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"\n}\n\n\nstxbil_accessreport_comar\nFj348jv0sMxss32N1cUrn1\ncomar.datamart.secutix.com\n'

# %%
# string formato username/password@host:port/serviceName
#connection = 'stxbil_accessreport_comar/Fj348jv0sMxss32N1cUrn1@comar.datamart.secutix.com:1521/COMAR.DATAMART'
connection = 'stxbil_accessreport_comar/Fj348jv0sMxss32N1cUrn1@comar.datamart.secutix.com:1521/18'

conexion = cx_Oracle.connect(connection)
cur = conexion.cursor()

# Configura los detalles de la conexión
usuario = "stxbil_accessreport_comar"
contraseña = "Fj348jv0sMxss32N1cUrn1"

# dsn = cx_Oracle.makedsn(
#     host="comar.datamart.secutix.com",
#     port=1521,
#     sid=18
# )

#dsn = "nombre_del_dsn"  # Esto podría ser algo como "(DESCRIPTION=(ADDRESS=(PROTOCOL=TCP)(HOST=hostname)(PORT=port))(CONNECT_DATA=(SID=sid)))"

# Crea una conexión a la base de datos
#conexion = cx_Oracle.connect(connection, timeout=60)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# c:\Users\Diego Torres\OneDrive\Python\My-Python\SQL en Python\connect_Oracle.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Torres/OneDrive/Python/My-Python/SQL%20en%20Python/connect_Oracle.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # string formato username/password@host:port/serviceName
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego%20Torres/OneDrive/Python/My-Python/SQL%20en%20Python/connect_Oracle.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> #connection = 'stxbil_accessreport_comar/Fj348jv0sMxss32N1cUrn1@comar.datamart.secutix.com:1521/COMAR.DATAMART'
# ...
